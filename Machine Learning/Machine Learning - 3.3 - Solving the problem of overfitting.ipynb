# %% [markdown]
# ## The Problem of Overfitting
# ![image.png](attachment:image.png)
#  - Overfitting - if we fit very high order polynomial, then the hypothesis can fit. it's almost as if it can fit any function and this face of possible hypothesis is just too large, its too variable and we dont have enough data to constrain it to give us a good hypothesis so that's called overfitting.
#  - Underfitting - or high bia, is when the form of our hyoothesis function h maps poorly to the trend of the data. its caused by a function that is too simple or uses too few features.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# i![image.png](attachment:image.png)
# When we have lot of features but very less training data, then overfitting can be a problem.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cost Function
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# When we get the value of theta matrix, we have no clue that which one corresponds to higher degree polynomials, so it seems intutive that we use smaller values for all theta values.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# lambda controls a trade off betweeen two different goals. The first goal is that we would like to fit the training data well and the second goal is that we want to keep the parameters small.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# it the lambda is set to very high number, than it will penalize very heavily for the high value of thetas and result in all the theta values equal to zero leaving only $\theta_0$, as it is not included in the cost function i.e. we dont penalise $\theta_0$

# %% [markdown]
# ### Regularized linear Regression
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Here n+1 is total number of features (including $x_1$)

# %% [markdown]
# ![image.png](attachment:image.png)
# Regularization also resolve the non-invertiblity issue that occurs when no of training data is less than no of features.
# Note: m < n
#
# $ \theta = (X^{T}X + \lambda.L)^{-1} X^{T}y $
# where L = is the matrix shown in the figure
#
# L has the dimension of (n+1)x(n+1).

# %% [markdown]
# ### Regularized logistics regression
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

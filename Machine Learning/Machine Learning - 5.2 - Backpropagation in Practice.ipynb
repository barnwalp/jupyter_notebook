# %% [markdown]
# ## Backpropagation in Practice
#
# ### Unrolling parameters
# optimization algorithm in octave assumes that initialTheta and gradient are vectors of size n+1
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Gradient Checking
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Random Initialization
# Initializing all theta weights to zero does not work with neural networks. when we backpropagate, all nodes will update to the same value repeatedly.
# ![image.png](attachment:image.png)

# %% [markdown]
# rand(x, y) is just a function in octave that will initialize a matrix of random real numbers between 0 and 1.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Putting it together
# ![image.png](attachment:image.png)

# %% [markdown]
# m is the no of training examples.
# ![image.png](attachment:image.png)

# %% [markdown]
# Since J(0) is non-convex here, gradient descent or advanced optimization may result in local minima instead of global minima
# ![image.png](attachment:image.png)
